# %%
import pandas as pd
from scipy.stats import pearsonr, spearmanr, kendalltau, permutation_test, norm
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import numpy as np
import os
import re

# %%
metric_results_kwtest = pd.read_csv('./keyWordLdaMataveTest/ldaMataveMetrics.csv')
metric_results_localraw = pd.read_csv('./rawLocalImplementation/localOnlineImplementation.csv')
human_results_kwtest = pd.read_csv('./keyWordLdaMataveTest/dataGeneration/experimentTestNoteShuffle/sent/humanResults.csv')
# Taken from LangChain paper (reported results): https://doi.org/10.1016/j.jbi.2025.104936
human_results_localraw = pd.DataFrame({
    "model": ['gpt3Notes', 'gpt4Notes'],
    "F1 Score": [0.8378, 0.6898] ,
    "Cohen's Kappa": [0.6331, 0.2674]
})

# %%
metric_results_kwtest
# Out:
#             model       CHI      ZIPF  CLASSIFIER      IRPR       FID  \
# 0  allTopicModels  0.000000  0.184044    0.967033  0.314002  0.759336
# 1             LDA  0.000000  0.172124    0.951994  0.306521  0.726224
# 2          MATAVE  0.000000  0.197774    0.983740  0.333860  0.837725
# 3      realToReal  0.667949  0.027829    0.452498  0.193086  0.241809
# 4     realToReal2  1.000000  0.047323    0.424715  0.189089  0.235171
# 5     realToReal3  1.000000  0.012167    0.484539  0.190729  0.244031
#
#          PR        DC     MAUVE  TRADITIONAL      ZERO
# 0  0.698251  0.932879  0.970704     0.510824  0.246050
# 1  0.645994  0.915669  0.973749     0.504291  0.262112
# 2  0.716517  0.941933  0.984797     0.518210  0.203755
# 3  0.117652  0.067015  0.030778     0.191097  0.091320
# 4  0.112295  0.060020  0.015929     0.164203  0.113025
# 5  0.127213  0.005042  0.021362     0.167957  0.098905

# %%
# make individual metric datasets 
individual_metrics_kwtest = pd.read_csv('./keyWordLdaMataveTest/outputScores/evaluated_scaled_results.csv')
individual_metrics_localraw = pd.read_csv('./rawLocalImplementation/outputScores/evaluated_scaled_results.csv')
all_individual_metrics = pd.concat([individual_metrics_kwtest, individual_metrics_localraw])
all_notes = all_individual_metrics.groupby('generation_type')['number_of_notes'].sum().reset_index()
all_individual_metrics = all_individual_metrics.drop(columns=['topic_model', 'dataset', 'needs', 'prompt_id', 'number_of_notes', 'sentiment', 'subjectivity'])
all_individual_metrics = all_individual_metrics.groupby('generation_type').mean().reset_index()

all_individual_metrics['model'] = [name.replace('fakeOnlineGPT3', 'gpt3Notes').replace('fakeOnlineGPT4', 'gpt4Notes') for name in all_individual_metrics['generation_type']]
all_individual_metrics['Original Metric Mean'] = all_individual_metrics['overall_score']
all_individual_metrics.drop(columns=['generation_type', 'overall_score'], inplace=True)
all_individual_metrics = all_individual_metrics[all_individual_metrics['model'] != 'fakeLocal']

# %%
all_notes
# Out:
#   generation_type  number_of_notes
# 0             LDA             2396
# 1          MATAVE             2313
# 2  allTopicModels             4709
# 3       fakeLocal             2385
# 4  fakeOnlineGPT3             5783
# 5  fakeOnlineGPT4             6253

# %%
metric_results_localraw = metric_results_localraw[(metric_results_localraw['dataset'] != 'realToReal') & (metric_results_localraw['dataset'] != 'realToReal2') & (metric_results_localraw['dataset'] != 'realToReal3')]
metric_results_localraw['model'] = metric_results_localraw['dataset']
metric_results_localraw = metric_results_localraw.drop(columns='dataset')
all_metric_comparisons = pd.concat([metric_results_kwtest, metric_results_localraw])
all_metric_comparisons = all_metric_comparisons[all_metric_comparisons['model'] != 'processedFakeNoteSyntheticNotes']

human_results_kwtest = human_results_kwtest.drop(columns=['Accuracy', 'Precision', 'Recall'])
all_human_comparisons = pd.concat([human_results_kwtest, human_results_localraw])

# %%
all_metric_comparisons
# Out:
#             model       CHI      ZIPF  CLASSIFIER      IRPR       FID  \
# 0  allTopicModels  0.000000  0.184044    0.967033  0.314002  0.759336
# 1             LDA  0.000000  0.172124    0.951994  0.306521  0.726224
# 2          MATAVE  0.000000  0.197774    0.983740  0.333860  0.837725
# 3      realToReal  0.667949  0.027829    0.452498  0.193086  0.241809
# 4     realToReal2  1.000000  0.047323    0.424715  0.189089  0.235171
# 5     realToReal3  1.000000  0.012167    0.484539  0.190729  0.244031
# 1       gpt3Notes  0.000000  0.136416    0.950653  0.326523  0.828887
# 2       gpt4Notes  0.000000  0.174486    0.975997  0.345340  0.916107
#
#          PR        DC     MAUVE  TRADITIONAL      ZERO
# 0  0.698251  0.932879  0.970704     0.510824  0.246050
# 1  0.645994  0.915669  0.973749     0.504291  0.262112
# 2  0.716517  0.941933  0.984797     0.518210  0.203755
# 3  0.117652  0.067015  0.030778     0.191097  0.091320
# 4  0.112295  0.060020  0.015929     0.164203  0.113025
# 5  0.127213  0.005042  0.021362     0.167957  0.098905
# 1  0.750784  0.949262  0.964472     0.500461  0.250659
# 2  0.771447  0.960601  0.986315     0.521236  0.278961

# %%
# Get metric columns. 
metric_cols = [c for c in all_metric_comparisons.columns if 'model' not in c]
# Extract real rows.
real_mask = all_metric_comparisons['model'].str.startswith('real')
real_df = all_metric_comparisons.loc[real_mask, metric_cols]

# %%
real_df
# Out:
#         CHI      ZIPF  CLASSIFIER      IRPR       FID        PR        DC  \
# 3  0.667949  0.027829    0.452498  0.193086  0.241809  0.117652  0.067015
# 4  1.000000  0.047323    0.424715  0.189089  0.235171  0.112295  0.060020
# 5  1.000000  0.012167    0.484539  0.190729  0.244031  0.127213  0.005042
#
#       MAUVE  TRADITIONAL      ZERO
# 3  0.030778     0.191097  0.091320
# 4  0.015929     0.164203  0.113025
# 5  0.021362     0.167957  0.098905

# %% [markdown]
# # Equal Weights for All Metrics

# %%
# There should be a minimum standard deviation, otherwise the metric is returning all 0s or exhibits no variation (which we assume is not indicative of a perfect metric, but a failing one).
min_std = 1e-6
# Get standard deviation. 
std_dev = real_df.std(ddof=1)
# Get mean. 
mean = real_df.mean()

weights = ((1 - (mean * 0)) / (1 + (mean * 0)).sum())
weights

# Calculate framework score.
distance = all_metric_comparisons.copy()
distance["Framework Score"] = (
    distance[metric_cols] * weights
).sum(axis=1)

merged = all_human_comparisons.merge(distance, on="model", how="inner")
weight_rank = weights.rank(ascending=False, method="dense").astype(int)
merged = merged.merge(all_individual_metrics, on='model', how="inner")

merged = merged.rename(columns={
    "final_score": "Framework Score",
    "bertscore": "BERTScore",
    "meteor": "METEOR",
    "abs_sentiment_diff": "Abs Sentiment Diff",
    "abs_subjectivity_diff": "Abs Subjectivity Diff",
    "original_metric_mean": "Original Metric Mean",
})

merged[['model', 'F1 Score', "Cohen's Kappa", 'Framework Score', 'Original Metric Mean']]

all_results_for_df = []
for comparison in ["F1 Score", "Cohen's Kappa"]:
    for metric in ["CHI", "ZIPF", "CLASSIFIER", "IRPR", "FID", "PR", "DC", "MAUVE", "TRADITIONAL", "ZERO", "Framework Score", "BERTScore", "METEOR", "Abs Sentiment Diff", "Abs Subjectivity Diff", "Original Metric Mean"]:
        x = merged[metric]
        y = merged[comparison]


        # Pearson is standardized and works best for linear relationships. 
        result = permutation_test(
            (x, y),
            lambda x, y: pearsonr(x, y).statistic,
            permutation_type="pairings",
            alternative="two-sided",
            n_resamples=np.inf
        )
        p_corr, pp_value = result.statistic, result.pvalue

        # Spearman's does not need linearity, robust to outliers, no distributional assumptions (non normal distribution), versatile in variable types.
        result = permutation_test(
            (x, y),
            lambda x, y: spearmanr(x, y).statistic,
            permutation_type="pairings",
            alternative="two-sided",
            n_resamples=np.inf
        )
        s_corr, sp_value = result.statistic, result.pvalue

        # Kendall's Tau as there is a very small sample size. 
        result = permutation_test(
            (x, y),
            lambda x, y: kendalltau(x, y).statistic,
            permutation_type="pairings",
            alternative="two-sided",
            n_resamples=np.inf
        )
        tau, kp_value = result.statistic, result.pvalue


        all_results_for_df.append({
        'metric': metric,
        'comparison': comparison,
        'pearson': p_corr,
        'pearson p-value': pp_value,
        'spearman': s_corr,
        'spearman p-value': sp_value,
        'kendall': tau, 
        'kendall p-value': kp_value,
        })

    plt.scatter(
    merged["Framework Score"],
    merged[comparison]
    )

    plt.xlabel("Final Calibrated Score")
    plt.ylabel(comparison)
    plt.title(f"Correlation: Final Calibrated Score vs {comparison}")
    plt.show()

    plt.scatter(
    merged["Original Metric Mean"],
    merged[comparison]
    )

    plt.xlabel("Final Individual Overall Score")
    plt.ylabel(comparison)
    plt.title(f"Correlation: Final Individual Overall Score vs {comparison}")
    plt.show()

statistical_tests = pd.DataFrame(all_results_for_df)
statistical_tests.to_csv(f'./ablation_ValidityNone_ReliabilityNone.csv')
print(statistical_tests[statistical_tests['metric'] == 'Framework Score'])
print(statistical_tests[statistical_tests['metric'] == 'Original Metric Mean'])
# Out:
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/2199518459.py:42: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/2199518459.py:52: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.999030         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.982071         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333

# %% [markdown]
# # Using Weighted [Reciprocal of Coefficient of Variation](https://doi.org/10.1016/B978-0-12-381375-6.00029-2) and Validity Weights

# %%
for val_ratio, rel_ratio in zip([round(0.1 * i, 1) for i in range(0, 11)], [round(0.1 * i, 1) for i in range(10, -1, -1)]):
    # There should be a minimum standard deviation, otherwise the metric is returning all 0s or exhibits no variation (which we assume is not indicative of a perfect metric, but a failing one).
    min_std = 1e-6
    # Get standard deviation. 
    std_dev = real_df.std(ddof=1)
    # Get mean. 
    mean = real_df.mean()

    # Remove saturated metrics
    valid_metrics = pd.Series(True, index=metric_cols)
    for m in metric_cols:
        # Real-vs-real values for this metric
        real_values = real_df[m]
        # Detect saturation at minimum or maximum or standard deviation is less than min_std
        if (np.allclose(real_values, 1, atol=min_std)
            or np.allclose(real_values, 0, atol=min_std)
            or std_dev[m] < min_std
        ):
            valid_metrics[m] = False

    # Get validity weights (as inverse score such that lower scores get higher weight) and remove saturated metrics. 
    validity_weights  = (1 - mean).where(valid_metrics, 0)
    # Normalize (relative importance, not arbitrary magnitude). 
    validity_weights = validity_weights / validity_weights.sum()

    # Get reliability weights (coefficient of variation, which is dimensionless and scale invariant).
    safe_std = std_dev.clip(lower=min_std)
    reliability_weights = 1 / (1 + (safe_std / mean))
    # Remove saturated metrics. 
    reliability_weights = reliability_weights.where(valid_metrics, 0)
    # Normalize (relative importance, not arbitrary magnitude). 
    reliability_weights = reliability_weights / reliability_weights.sum()

    # Combine weights. 
    weights = ((validity_weights * val_ratio) + (reliability_weights * rel_ratio)) / 2
    # Normalize (relative importance, not arbitrary magnitude). 
    weights = weights / weights.sum()

    # Calculate framework score.
    distance = all_metric_comparisons.copy()
    distance["Framework Score"] = (
        distance[metric_cols] * weights
    ).sum(axis=1)

    merged = all_human_comparisons.merge(distance, on="model", how="inner")
    weight_rank = weights.rank(ascending=False, method="dense").astype(int)
    merged = merged.merge(all_individual_metrics, on='model', how="inner")

    merged = merged.rename(columns={
        "final_score": "Framework Score",
        "bertscore": "BERTScore",
        "meteor": "METEOR",
        "abs_sentiment_diff": "Abs Sentiment Diff",
        "abs_subjectivity_diff": "Abs Subjectivity Diff",
        "original_metric_mean": "Original Metric Mean",
    })

    merged[['model', 'F1 Score', "Cohen's Kappa", 'Framework Score', 'Original Metric Mean']]

    all_results_for_df = []
    for comparison in ["F1 Score", "Cohen's Kappa"]:
        for metric in ["CHI", "ZIPF", "CLASSIFIER", "IRPR", "FID", "PR", "DC", "MAUVE", "TRADITIONAL", "ZERO", "Framework Score", "BERTScore", "METEOR", "Abs Sentiment Diff", "Abs Subjectivity Diff", "Original Metric Mean"]:
            x = merged[metric]
            y = merged[comparison]


            # Pearson is standardized and works best for linear relationships. 
            result = permutation_test(
                (x, y),
                lambda x, y: pearsonr(x, y).statistic,
                permutation_type="pairings",
                alternative="two-sided",
                n_resamples=np.inf
            )
            p_corr, pp_value = result.statistic, result.pvalue

            # Spearman's does not need linearity, robust to outliers, no distributional assumptions (non normal distribution), versatile in variable types.
            result = permutation_test(
                (x, y),
                lambda x, y: spearmanr(x, y).statistic,
                permutation_type="pairings",
                alternative="two-sided",
                n_resamples=np.inf
            )
            s_corr, sp_value = result.statistic, result.pvalue

            # Kendall's Tau as there is a very small sample size. 
            result = permutation_test(
                (x, y),
                lambda x, y: kendalltau(x, y).statistic,
                permutation_type="pairings",
                alternative="two-sided",
                n_resamples=np.inf
            )
            tau, kp_value = result.statistic, result.pvalue


            all_results_for_df.append({
            'metric': metric,
            'comparison': comparison,
            'pearson': p_corr,
            'pearson p-value': pp_value,
            'spearman': s_corr,
            'spearman p-value': sp_value,
            'kendall': tau, 
            'kendall p-value': kp_value,
            })

    statistical_tests = pd.DataFrame(all_results_for_df)
    statistical_tests.to_csv(f'./ablation_Validity{val_ratio}_Reliability{rel_ratio}.csv')
    print(f"---------- Validity {val_ratio} vs Reliability {rel_ratio} ----------")
    print(statistical_tests[statistical_tests['metric'] == 'Framework Score'])
    print(statistical_tests[statistical_tests['metric'] == 'Original Metric Mean'])
# Out:
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.0 vs Reliability 1.0 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.996905         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.984973         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.1 vs Reliability 0.9 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.997196         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985056         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.2 vs Reliability 0.8 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.997472         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985123         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.3 vs Reliability 0.7 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.997733         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985173         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.4 vs Reliability 0.6 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.997977         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985207         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.5 vs Reliability 0.5 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.998206         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985223         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.6 vs Reliability 0.4 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.998418         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985222         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.7 vs Reliability 0.3 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.998613         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985203         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.8 vs Reliability 0.2 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.998791         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985166         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 0.9 vs Reliability 0.1 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.998952         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985110         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:70: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: pearsonr(x, y).statistic,
# /var/folders/12/p5c0vdcj3yx9xb69fcd0n3j80000gn/T/ipykernel_7490/1272075241.py:80: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   lambda x, y: spearmanr(x, y).statistic,
# ---------- Validity 1.0 vs Reliability 0.0 ----------
#              metric     comparison   pearson  pearson p-value  spearman  \
# 10  Framework Score       F1 Score -0.999095         0.016667      -1.0
# 26  Framework Score  Cohen's Kappa -0.985036         0.016667      -1.0
#
#     spearman p-value  kendall  kendall p-value
# 10          0.016667     -1.0         0.016667
# 26          0.016667     -1.0         0.016667
#                   metric     comparison   pearson  pearson p-value  spearman  \
# 15  Original Metric Mean       F1 Score  0.660056         0.183333       0.8
# 31  Original Metric Mean  Cohen's Kappa  0.518658         0.316667       0.8
#
#     spearman p-value  kendall  kendall p-value
# 15          0.133333      0.6         0.233333
# 31          0.133333      0.6         0.233333

# %%
all_results = []

for file in os.listdir("./"):

    if not os.path.isdir(f"./{file}"):

        if file.endswith(".csv") and "ablation_" in file:

            match = re.search(
                r"Validity(\d+(?:\.\d+)?)_Reliability(\d+(?:\.\d+)?)\.csv$",
                file
            )

            if match is not None:

                validity = float(match.group(1))
                reliability = float(match.group(2))
            elif file == "ablation_ValidityNone_ReliabilityNone.csv":

                validity = None
                reliability = None

            else:
                print(f"Could not parse filename: {file}")
                continue


            temp_df = pd.read_csv(f"./{file}")

            temp_df = temp_df[
                temp_df["metric"] == "Framework Score"
            ].drop(
                columns=["metric", "Unnamed: 0"],
                errors="ignore"
            )

            temp_df["validity"] = validity
            temp_df["reliability"] = reliability
            temp_df["filename"] = file

            all_results.append(temp_df)


results = pd.concat(
    all_results,
    ignore_index=True
)

# %%
results
# Out:
#        comparison   pearson  pearson p-value  spearman  spearman p-value  \
# 0        F1 Score -0.999030         0.016667      -1.0          0.016667
# 1   Cohen's Kappa -0.982071         0.016667      -1.0          0.016667
# 2        F1 Score -0.996905         0.016667      -1.0          0.016667
# 3   Cohen's Kappa -0.984973         0.016667      -1.0          0.016667
# 4        F1 Score -0.997196         0.016667      -1.0          0.016667
# 5   Cohen's Kappa -0.985056         0.016667      -1.0          0.016667
# 6        F1 Score -0.997472         0.016667      -1.0          0.016667
# 7   Cohen's Kappa -0.985123         0.016667      -1.0          0.016667
# 8        F1 Score -0.997733         0.016667      -1.0          0.016667
# 9   Cohen's Kappa -0.985173         0.016667      -1.0          0.016667
# 10       F1 Score -0.997977         0.016667      -1.0          0.016667
# 11  Cohen's Kappa -0.985207         0.016667      -1.0          0.016667
# 12       F1 Score -0.998206         0.016667      -1.0          0.016667
# 13  Cohen's Kappa -0.985223         0.016667      -1.0          0.016667
# 14       F1 Score -0.998418         0.016667      -1.0          0.016667
# 15  Cohen's Kappa -0.985222         0.016667      -1.0          0.016667
# 16       F1 Score -0.998613         0.016667      -1.0          0.016667
# 17  Cohen's Kappa -0.985203         0.016667      -1.0          0.016667
# 18       F1 Score -0.998791         0.016667      -1.0          0.016667
# 19  Cohen's Kappa -0.985166         0.016667      -1.0          0.016667
# 20       F1 Score -0.998952         0.016667      -1.0          0.016667
# 21  Cohen's Kappa -0.985110         0.016667      -1.0          0.016667
# 22       F1 Score -0.999095         0.016667      -1.0          0.016667
# 23  Cohen's Kappa -0.985036         0.016667      -1.0          0.016667
#
#     kendall  kendall p-value validity reliability  \
# 0      -1.0         0.016667     None        None
# 1      -1.0         0.016667     None        None
# 2      -1.0         0.016667      0.0         1.0
# 3      -1.0         0.016667      0.0         1.0
# 4      -1.0         0.016667      0.1         0.9
# 5      -1.0         0.016667      0.1         0.9
# 6      -1.0         0.016667      0.2         0.8
# 7      -1.0         0.016667      0.2         0.8
# 8      -1.0         0.016667      0.3         0.7
# 9      -1.0         0.016667      0.3         0.7
# 10     -1.0         0.016667      0.4         0.6
# 11     -1.0         0.016667      0.4         0.6
# 12     -1.0         0.016667      0.5         0.5
# 13     -1.0         0.016667      0.5         0.5
# 14     -1.0         0.016667      0.6         0.4
# 15     -1.0         0.016667      0.6         0.4
# 16     -1.0         0.016667      0.7         0.3
# 17     -1.0         0.016667      0.7         0.3
# 18     -1.0         0.016667      0.8         0.2
# 19     -1.0         0.016667      0.8         0.2
# 20     -1.0         0.016667      0.9         0.1
# 21     -1.0         0.016667      0.9         0.1
# 22     -1.0         0.016667      1.0         0.0
# 23     -1.0         0.016667      1.0         0.0
#
#                                      filename
# 0   ablation_ValidityNone_ReliabilityNone.csv
# 1   ablation_ValidityNone_ReliabilityNone.csv
# 2     ablation_Validity0.0_Reliability1.0.csv
# 3     ablation_Validity0.0_Reliability1.0.csv
# 4     ablation_Validity0.1_Reliability0.9.csv
# 5     ablation_Validity0.1_Reliability0.9.csv
# 6     ablation_Validity0.2_Reliability0.8.csv
# 7     ablation_Validity0.2_Reliability0.8.csv
# 8     ablation_Validity0.3_Reliability0.7.csv
# 9     ablation_Validity0.3_Reliability0.7.csv
# 10    ablation_Validity0.4_Reliability0.6.csv
# 11    ablation_Validity0.4_Reliability0.6.csv
# 12    ablation_Validity0.5_Reliability0.5.csv
# 13    ablation_Validity0.5_Reliability0.5.csv
# 14    ablation_Validity0.6_Reliability0.4.csv
# 15    ablation_Validity0.6_Reliability0.4.csv
# 16    ablation_Validity0.7_Reliability0.3.csv
# 17    ablation_Validity0.7_Reliability0.3.csv
# 18    ablation_Validity0.8_Reliability0.2.csv
# 19    ablation_Validity0.8_Reliability0.2.csv
# 20    ablation_Validity0.9_Reliability0.1.csv
# 21    ablation_Validity0.9_Reliability0.1.csv
# 22    ablation_Validity1.0_Reliability0.0.csv
# 23    ablation_Validity1.0_Reliability0.0.csv

# %%
df_flat = (
    results.pivot(
        index=["validity", "reliability", "filename"],
        columns="comparison",
        values=["pearson", "pearson p-value",
                "spearman", "spearman p-value",
                "kendall", "kendall p-value"]
    )
    .reset_index()
)

df_flat.columns = [
    "_".join(col).strip("_") if isinstance(col, tuple) else col
    for col in df_flat.columns
]

df_flat.drop(columns=[column for column in df_flat.columns if 'spearman' in column or 'kendall' in column or 'filename' in column])
# Out:
#     validity  reliability  pearson_Cohen's Kappa  pearson_F1 Score  \
# 0        NaN          NaN              -0.982071         -0.999030
# 1        0.0          1.0              -0.984973         -0.996905
# 2        0.1          0.9              -0.985056         -0.997196
# 3        0.2          0.8              -0.985123         -0.997472
# 4        0.3          0.7              -0.985173         -0.997733
# 5        0.4          0.6              -0.985207         -0.997977
# 6        0.5          0.5              -0.985223         -0.998206
# 7        0.6          0.4              -0.985222         -0.998418
# 8        0.7          0.3              -0.985203         -0.998613
# 9        0.8          0.2              -0.985166         -0.998791
# 10       0.9          0.1              -0.985110         -0.998952
# 11       1.0          0.0              -0.985036         -0.999095
#
#     pearson p-value_Cohen's Kappa  pearson p-value_F1 Score
# 0                        0.016667                  0.016667
# 1                        0.016667                  0.016667
# 2                        0.016667                  0.016667
# 3                        0.016667                  0.016667
# 4                        0.016667                  0.016667
# 5                        0.016667                  0.016667
# 6                        0.016667                  0.016667
# 7                        0.016667                  0.016667
# 8                        0.016667                  0.016667
# 9                        0.016667                  0.016667
# 10                       0.016667                  0.016667
# 11                       0.016667                  0.016667

# %%
y_lower = -1.0
y_upper = -0.98

fig, ax = plt.subplots(figsize=(10, 5))


line_colors = {}

for comparison in ["F1 Score", "Cohen's Kappa"]:

    subset = results[
        results["comparison"] == comparison
    ].copy()

    normal = subset[
        subset["validity"].notna()
    ].sort_values(
        "validity",
        ascending=False
    )

    equal_weights = subset[
        subset["validity"].isna()
    ]

    subset = pd.concat(
        [normal, equal_weights],
        ignore_index=True
    )

    x = np.arange(len(subset))

    y = subset["pearson"].values
    p = subset["pearson p-value"].values

    line, = ax.plot(
        x,
        y,
        linewidth=2,
        label=comparison
    )

    # Store the colour used for this line
    line_colors[comparison] = line.get_color()

    significant = p < 0.05

    ax.scatter(
        x[significant],
        y[significant],
        s=60,
        color=line.get_color(),
        zorder=3
    )

    ax.scatter(
        x[~significant],
        y[~significant],
        s=60,
        facecolors="none",
        edgecolors=line.get_color(),
        linewidths=1.5,
        zorder=3
    )


normal = results[
    (results["comparison"] == "F1 Score") &
    (results["validity"].notna())
].sort_values(
    "validity",
    ascending=False
)

equal_weights = results[
    (results["comparison"] == "F1 Score") &
    (results["validity"].isna())
]

n_normal = len(normal)

labels = [
    f"{v:.1f}"
    for v in normal["validity"]
]

if len(equal_weights) > 0:
    labels.append("Equal\nweights")

ax.set_xticks(
    np.arange(len(labels))
)

ax.set_xticklabels(labels)

ax.set_xlabel(
    "Validity → Reliability"
)

ax.set_ylabel(
    "Pearson correlation"
)

if len(equal_weights) > 0:

    equal_x = n_normal

    ax.axvline(
        equal_x - 0.5,
        linestyle=":",
        linewidth=1,
        alpha=0.7
    )

ax.set_ylim(
    y_lower,
    y_upper
)


ax.axhline(
    0,
    linestyle="--",
    linewidth=1,
    alpha=0.5
)


ax.grid(
    axis="y",
    alpha=0.2
)


line_handles = [
    Line2D(
        [0],
        [0],
        color=line_colors["F1 Score"],
        linewidth=2,
        label="F1 Score"
    ),
    Line2D(
        [0],
        [0],
        color=line_colors["Cohen's Kappa"],
        linewidth=2,
        label="Cohen's Kappa"
    )
]

sig_handles = [
    Line2D(
        [0],
        [0],
        marker="o",
        linestyle="None",
        markersize=7,
        markerfacecolor="black",
        markeredgecolor="black",
        label="p < .05"
    ),
    Line2D(
        [0],
        [0],
        marker="o",
        markerfacecolor="none",
        markeredgecolor="black",
        linestyle="None",
        markersize=7,
        label="p ≥ .05"
    )
]

ax.legend(
    handles=line_handles + sig_handles,
    frameon=False
)


plt.tight_layout()
plt.savefig('./AblationTests.png', dpi='figure', bbox_inches=None)
plt.show()
